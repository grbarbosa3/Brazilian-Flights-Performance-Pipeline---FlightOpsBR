# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Dev\\Zoomcamp\\final-project\\data\\raw\\airports.csv')

# %%
df.head(5)
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total RF Heliport     40.070985
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.947733
# 3    6525  00AL  small_airport          Epps Airpark     34.864799
# 4  506791  00AN  small_airport  Katmai Lodge Airport     59.093287
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933689          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.692524         450.0       NaN          US      US-AK  Anchor Point
# 3     -86.770302         820.0       NaN          US      US-AL       Harvest
# 4    -156.456699          80.0       NaN          US      US-AK   King Salmon
#
#   scheduled_service icao_code iata_code gps_code local_code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 85147 entries, 0 to 85146
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 85147 non-null  int64
#  1   ident              85147 non-null  str
#  2   type               85147 non-null  str
#  3   name               85147 non-null  str
#  4   latitude_deg       85147 non-null  float64
#  5   longitude_deg      85147 non-null  float64
#  6   elevation_ft       70421 non-null  float64
#  7   continent          45622 non-null  str
#  8   iso_country        84844 non-null  str
#  9   iso_region         85147 non-null  str
#  10  municipality       80446 non-null  str
#  11  scheduled_service  85147 non-null  str
#  12  icao_code          9926 non-null   str
#  13  iata_code          9061 non-null   str
#  14  gps_code           44123 non-null  str
#  15  local_code         36021 non-null  str
#  16  home_link          4683 non-null   str
# ...
