# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Dev\\Zoomcamp\\final-project\\VRA_202510.csv', sep=';', skiprows=1)

# %%
df.head(5)
# Out:
#   ICAO Empresa Aérea Número Voo Código Autorização (DI) Código Tipo Linha  \
# 0                LPE       2423                       0                 I
# 1                LPE       2423                       0                 I
# 2                LPE       2423                       0                 I
# 3                LPE       2423                       0                 I
# 4                LPE       2428                       0                 I
#
#   ICAO Aeródromo Origem ICAO Aeródromo Destino     Partida Prevista  \
# 0                  SBPA                   SPJC  2025-10-23 07:20:00
# 1                  SBPA                   SPJC  2025-10-25 07:20:00
# 2                  SBPA                   SPJC  2025-10-27 07:45:00
# 3                  SBPA                   SPJC  2025-10-30 07:45:00
# 4                  SPJC                   SBGR  2025-10-01 01:15:00
#
#           Partida Real     Chegada Prevista         Chegada Real Situação Voo  \
# ...

# %%
len(df)
# Out:
# 85828

# %%
df[df['Situação Voo']=='CANCELADO']
# Out:
#       ICAO Empresa Aérea Número Voo Código Autorização (DI) Código Tipo Linha  \
# 67135                LCO       3613                       0                 G
# 69496                1ED       1234                       0                 I
# 69497                1ED       1234                       0                 I
# 69498                ACN       5444                       0                 N
# 69499                ACN       5445                       0                 N
# ...                  ...        ...                     ...               ...
# 77054                TAM       3911                       0                 N
# 77055                TAM       3920                       0                 N
# 77056                TAM       3935                       0                 N
# 77057                TAM       4526                       0                 N
# 77058                TAP       0075                       0                 I
#
# ...

# %%
df['ICAO Aeródromo Origem'].value_counts()
# Out:
# ICAO Aeródromo Origem
# SBGR    12614
# SBSP     8237
# SBGL     5352
# SBKP     5316
# SBBR     5238
#         ...
# SKCC        1
# DGAA        1
# GCTS        1
# SBBP        1
# KTPA        1
# Name: count, Length: 243, dtype: int64

# %%
aero_publicos['CÓDIGO OACI'].value_counts()
# Out:
# CÓDIGO OACI
# SBAA    1
# SBAE    1
# SBAQ    1
# SBAR    1
# SBAT    1
#        ..
# SBPW    1
# SSBG    1
# SND4    1
# SND6    1
# SD5Q    1
# Name: count, Length: 501, dtype: int64

# %%
aero_publicos = pd.read_csv('C:\\Dev\\Zoomcamp\\final-project\\cadastro-de-aerodromos-civis-publicos.csv', sep=';', skiprows=1, on_bad_lines='skip', engine='python')

# %%
aero_publicos.head(5)
# Out:
#   CÓDIGO OACI    CIAD                         NOME     MUNICÍPIO ATENDIDO  UF  \
# 0        SBAA  PA0008        CONCEIÇÃO DO ARAGUAIA  CONCEIÇÃO DO ARAGUAIA  PA
# 1        SBAE  SP0010                BAURU/AREALVA                  BAURU  SP
# 2        SBAQ  SP0012         BARTOLOMEU DE GUSMÃO             ARARAQUARA  SP
# 3        SBAR  SE0001                  SANTA MARIA                ARACAJU  SE
# 4        SBAT  MT0003  PILOTO OSVALDO MARQUES DIAS          ALTA FLORESTA  MT
#
#          LATITUDE       LONGITUDE ALTITUDE  \
# 0   8° 20' 55'' S  49° 18' 11'' W    199 m
# 1   22° 9' 28'' S    49° 4' 6'' W    598 m
# 2  21° 48' 43'' S   48° 7' 59'' W    711 m
# 3   10° 59' 7'' S   37° 4' 24'' W      7 m
# 4   9° 51' 59'' S   56° 6' 18'' W    289 m
#
#                                   OPERAÇÃO OACI  ... CAT SESCINC           r1  \
# 0          VFR Diurno/Noturno e IFR Diurno    -  ...           0            -
# ...

# %%
aero_privados = pd.read_csv(r'C:\Dev\Zoomcamp\final-project\data\raw\AerodromosPrivados.csv', encoding='latin-1', sep=';', skiprows=1)

# %%
aero_publicos = pd.read_csv(r'C:\Dev\Zoomcamp\final-project\data\raw\AerodromosPublicos.csv', encoding='latin-1', sep=';', skiprows=1)

# %%
aero_publicos.head(5)
# Out:
#   Código OACI    CIAD                                  Nome    Município  \
# 0        SDZG  CE0008  Pedro Teixeira Castelo Regional Tauá         TAUÁ
# 1        SDIG  SP0038                              Ibitinga     IBITINGA
# 2        SBVT  ES0001               Eurico de Aguiar Salles      VITÓRIA
# 3        SNJK  BA0047                                Jequié       JEQUIÉ
# 4        SSKU  SC0016                Lauro Antônio da Costa  CURITIBANOS
#
#                UF Município Servido      UF Servido  LATGEOPOINT  LONGEOPOINT  \
# 0           Ceará              Tauá           Ceará    -5.933333   -40.297500
# 1       São Paulo          Ibitinga       São Paulo   -21.747222   -48.855833
# 2  Espírito Santo           Vitória  Espírito Santo   -20.258056   -40.286389
# 3           Bahia            Jequié           Bahia   -13.877778   -40.071389
# 4  Santa Catarina       Curitibanos  Santa Catarina   -27.287222   -50.603889
#
# ...

# %%
aero_privados.head(5)
# Out:
#   Código OACI    CIAD                    Nome                 Município  UF  \
# 0        SN8C  MS0728           Fazenda Maria                   CARACOL  MS
# 1        SIF9  TO0134            Fazenda Rios  BRASILÂNDIA DO TOCANTINS  TO
# 2        SDX4  PI0093         Canto do Buriti           CANTO DO BURITI  PI
# 3        SIS8  RR0153  Fazenda Belo Horizonte                   AMAJARI  RR
# 4        SIVO  MT0142            Fazenda Malu     BOM JESUS DO ARAGUAIA  MT
#
#         Longitude       Latitude Altitude Operação Diurna Operação Noturna  \
# 0     057°07'21"W     22°05'43"S       ,0             VFR     Sem Operação
# 1     048°29'15"W     08°21'08"S       ,0             VFR     Sem Operação
# 2  042°59'24,65"W  08°07'34,62"S    292,0             VFR     Sem Operação
# 3  061°24'18,05"W  03°32'39,84"N    121,0             VFR     Sem Operação
# 4     051°46'27"W     12°26'53"S    356,0             VFR     Sem Operação
#
# ...

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import xlrd

# %%
empresas = pd.read_excel(r'C:\Dev\Zoomcamp\final-project\data\raw\glossario_de_empresas_aereas.xls',skiprows=3)

# %%
empresas[empresas['Sigla OACI'] == 'ARE']
# Out:
#     Unnamed: 0 Sigla OACI                  Nome Empresas  Unnamed: 3  \
# 14         NaN        ARE  AIRES AEROVIAS DE INTEGRACION         NaN
#
#    Nacional ou Estrangeira
# 14             ESTRANGEIRA
